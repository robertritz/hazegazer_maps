# %% [markdown]
# # Soil Map Creation

# %% [markdown]
# This notebook creates a heatmap showing heavy metal soil pollution in Ulaanbaatar, Mongolia. Data were collected in April/July 2022 by faculty and students from the Mongolian National University and the Mongolian University of Science and Technology.

# %% [markdown]
# Many tests were performed on the soil samples collected, and this analysis focuses on the most harmful heavy metals. Mongolia, via [MNS5850:2019](https://estandard.gov.mn/standard/reader/1300#3-wpwpfkvqlrmcpayq.jpg), sets standards on harful and dangerous levels of many heavy metals. Those levels are:
#
# | Metal        | Unit | Expected | Harmful | Dangerous |
# | ------------ | ---- | -------- | ------- | --------- |
# | Arsenic (As) | ppm  | 20       | 50      | 100       |
# | Cadmium (Cd) | ppm  | 3        | 10      | 20        |
# | Chromium (Cr) | ppm  | 150        | 400      | 1500        |
# | Lead (Pb)    | ppm  | 100      | 500     | 1200      |
# | Zinc (Zn)    | ppm  | 300      | 600     | 1000      |
# | Nickel (Ni)  | ppm  | 150      | 1000    | 1800      |

# %%
import pandas as pd
import numpy as np
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern
from sklearn.gaussian_process.kernels import RBF

import psycopg2
import sqlalchemy as db

import datetime
import os

import plotly.graph_objects as go
import folium
from folium.plugins import FeatureGroupSubGroup

# %%
mapbox_token = os.environ["MAPBOX_TOKEN"]
github_username = os.environ["GITHUB_USERNAME"]
github_key = os.environ["GITHUB_KEY"]

# %%
locations = pd.read_csv("locations.csv")
df = pd.read_csv("data/Water and Soil Combined.csv")

# %%
metals = ['As','Cd','Cr','Pb','Zn','Ni']
df = df[df['Names'].isin(metals)]

# %%
df['Names'].unique()
# Out:
# array(['As', 'Cd', 'Cr', 'Ni', 'Pb', 'Zn'], dtype=object)

# %%
df = df.drop(columns=['METHOD','LDETECTION','UDETECTION'])

# %% [markdown]
# The water pollutants are measured in PPB while the soil ones are measured in PPM.

# %%
df = df.melt(id_vars=['DATE','Names','UNITS'], var_name='location')

# %%
df = df.dropna()

# %%
df['Names'].unique()
# Out:
# array(['As', 'Cd', 'Cr', 'Ni', 'Pb', 'Zn'], dtype=object)

# %%
df.loc[df['value'].str.contains("<"), 'value'] = 0

# %%
df['value'] = df['value'].astype('float')

# %%
df = df[df['location'].str.contains("HZS")]

# %%
df = df.drop(columns='UNITS')

# %% [markdown]
# Group by location and date.

# %%
df = df.groupby(by=['Names', 'location', 'DATE']).mean().reset_index()

# %%
df['location'] = df['location'].str.replace("-","")

# %%
locations['lat'] = locations['Decimal Degrees (DD)'].str.split(", ").str.get(0).astype('float')
locations['lon'] = locations['Decimal Degrees (DD)'].str.split(", ").str.get(1).astype('float')

# %%
df = df.merge(locations[['Code','lat','lon']], how='left', left_on='location', right_on='Code')

# %%
raw_values = df.copy()

# %% [markdown]
# ## Make cuts

# %% [markdown]
# In order to make the heatmap for all data from a particular

# %%
as_bins = [0, 20, 50, 100, 10000]
cd_bins = [0, 3, 10, 20, 10000]
cr_bins = [0, 150, 400, 1500, 10000]
pb_bins = [0, 100, 500, 1200, 10000]
zn_bins = [0, 300, 600, 1000, 10000]
ni_bins = [0, 150, 1000, 1800, 10000]

# %%
df.loc[df['Names'] == 'As', 'value'] = pd.cut(df[df['Names'] == 'As']['value'], as_bins, labels=False, include_lowest=True)
df.loc[df['Names'] == 'Cd', 'value'] = pd.cut(df[df['Names'] == 'Cd']['value'], cd_bins, labels=False, include_lowest=True)
df.loc[df['Names'] == 'Cr', 'value'] = pd.cut(df[df['Names'] == 'Cr']['value'], cr_bins, labels=False, include_lowest=True)
df.loc[df['Names'] == 'Pb', 'value'] = pd.cut(df[df['Names'] == 'Pb']['value'], pb_bins, labels=False, include_lowest=True)
df.loc[df['Names'] == 'Zn', 'value'] = pd.cut(df[df['Names'] == 'Zn']['value'], zn_bins, labels=False, include_lowest=True)
df.loc[df['Names'] == 'Ni', 'value'] = pd.cut(df[df['Names'] == 'Ni']['value'], ni_bins, labels=False, include_lowest=True)

# %% [markdown]
# Similar to AQI, we will take the maximum value for each heavy metal. This will be our toxicity level. After all, a dangerous level of only one heavy metal is dangerous. Averaging the levels will only reduce the actual, which would not make sense.

# %%
df = df.groupby(by=['DATE', 'location']).max().reset_index().drop(columns=['Names','Code'])

# %%
df
# Out:
#           DATE location  value        lat         lon
# 0   2022.04.01     HZS1    1.0  47.930083  107.003889
# 1   2022.04.01     HZS2    1.0  47.945750  106.913778
# 2   2022.04.01     HZS3    1.0  47.942694  106.902917
# 3   2022.04.01     HZS4    0.0  47.944219  106.888398
# 4   2022.04.01     HZS5    1.0  47.999493  106.792462
# 5   2022.04.01     HZS6    2.0  47.934220  106.840740
# 6   2022.04.01     HZS7    1.0  47.827600  106.682600
# 7   2022.04.01     HZS8    3.0  47.891200  106.892200
# 8   2022.04.01     HZS9    1.0  47.896500  106.758400
# 9   2022.07.01     HZS1    0.0  47.930083  107.003889
# 10  2022.07.01     HZS2    0.0  47.945750  106.913778
# 11  2022.07.01     HZS3    0.0  47.942694  106.902917
# 12  2022.07.01     HZS4    0.0  47.944219  106.888398
# 13  2022.07.01     HZS5    0.0  47.999493  106.792462
# 14  2022.07.01     HZS6    2.0  47.934220  106.840740
# 15  2022.07.01     HZS7    0.0  47.827600  106.682600
# 16  2022.07.01     HZS8    3.0  47.891200  106.892200
# 17  2022.07.01     HZS9    0.0  47.896500  106.758400
# 18  2022.09.01     HZS1    0.0  47.930083  107.003889
# 19  2022.09.01     HZS2    0.0  47.945750  106.913778
# 20  2022.09.01     HZS3    0.0  47.942694  106.902917
# 21  2022.09.01     HZS4    2.0  47.944219  106.888398
# 22  2022.09.01     HZS5    0.0  47.999493  106.792462
# 23  2022.09.01     HZS6    0.0  47.934220  106.840740
# 24  2022.09.01     HZS7    0.0  47.827600  106.682600
# 25  2022.09.01     HZS8    2.0  47.891200  106.892200
# 26  2022.09.01     HZS9    0.0  47.896500  106.758400

# %% [markdown]
# ### Add colors by location

# %%
color_map = {0: '#878787', 1: '#ffff00', 2:'#ff7e00', 3: '#ff0000'}

# %%
df['color'] = df['value'].map(color_map)

# %% [markdown]
# ## Map Code

# %% [markdown]
# ### English

# %% [markdown]
# New strategy, combine all heavy metals into one heatmap and then make a new layer for each time period (April, July, September). Call it heavy metal pollution in soil and water.

# %%
df['DATE'] = pd.to_datetime(df['DATE']).dt.strftime("%m-%Y")

# %%
locations[locations['Code'].str.contains('HZS')]['Code']
# Out:
# 9     HZS1
# 10    HZS2
# 11    HZS3
# 12    HZS4
# 13    HZS5
# 14    HZS6
# 15    HZS7
# 16    HZS8
# 17    HZS9
# Name: Code, dtype: object

# %%
metal_map_en = {'As':'Arsenic','Cd':'Cadmium','Cr':'Chromium','Pb':'Lead','Zn':'Zinc','Ni':'Nickel'}
metal_map_mn = {'As':'Хүнцэл','Cd':'Кадми','Cr':'Хром','Pb':'Тэргүүлэх','Zn':'Цайр','Ni':'Никель'}

# %%
metal_map_en['As']
# Out:
# 'Arsenic'

# %%
locations
# Out:
#     Code                            Location  \
# 0   HZW1  1-r horoollin hurin us hayah suvag
# 1   HZW2                  Sonsgolongiin guur
# 2   HZW3        TTsB-iin hayagdal usni suvag
# 3   HZW4                  Biokombinatin guur
# 4   HZW5                          Zuun Selbe
# 5   HZW6                        32-in toirog
# 6   HZW7                     Nuden nuur SKHD
# 7   HZW8                         Nogoon nuur
# 8   HZW9                        Uliastai gol
# 9   HZS1                       Da Khuree zah
# 10  HZS2                3n buudal, 32 toirog
# 11  HZS3                    Denjiin 1000 zah
# 12  HZS4                           70 davhar
# 13  HZS5                       Ulaan chuluut
# 14  HZS6                     SKHD 7-r khoroo
# 15  HZS7          Biokombinatin khogiin tseg
# 16  HZS8             Khargia TSB iin khashaa
# 17  HZS9                   TS4-iin unsen san
#
#                                      Location MNG   Decimal Degrees (DD)  \
# 0               1-р хорооллын хурын ус хаях суваг    47.91441, 106.83008
# 1                              Сонсголонгийн гүүр    47.87316, 106.78448
# 2   Төв цэвэрлэх байгууламжийн хаягдал усны суваг      47.8906, 106.7349
# 3                              Биокомбинатын гүүр      47.8484, 106.6761
# 4                                      Зүүн Сэлбэ  47.925750, 106.931500
# 5                                     32-н тойрог  47.942462, 106.927077
# 6                                  Нүдэн нуур СХД   47.94845, 106.839092
# 7                                     Ногоон нуур  47.929758, 106.908208
# 8                                    Улиастай гол  47.920444, 107.023583
# 9                                        Да Хүрээ  47.930083, 107.003889
# 10                        3-н буудал, 32-н тойрог  47.945750, 106.913778
# 11                             Дэнжийн 1000-н зах  47.942694, 106.902917
# 12                                      70 давхар  47.944219, 106.888398
# 13                                   Улаан чулуут  47.999493, 106.792462
# 14                                   СХД 7- хороо  47.934220, 106.840740
# 15                       Биокомбинатын хогийн цэг      47.8276, 106.6826
# 16                            Харгиа ЦБ-ийн хашаа      47.8912, 106.8922
# 17                             ТЭЦ4-ийн үнсэн сан      47.8965, 106.7584
#
#       Degrees, min, secs (DMS) University Sample        lat         lon
# 0   47°54'51.9"N 106°49'48.3"E       MUST  Water  47.914410  106.830080
# 1   47°52'23.4"N 106°47'04.1"E       MULS  Water  47.873160  106.784480
# 2   47°53'26.2"N 106°44'05.6"E       MULS  Water  47.890600  106.734900
# 3   47°50'54.2"N 106°40'34.0"E       MULS  Water  47.848400  106.676100
# 4   47°55'32.7"N 106°55'53.4"E       MUST  Water  47.925750  106.931500
# 5   47°56'32.9"N 106°55'37.5"E        NUM  Water  47.942462  106.927077
# 6   47°56'54.4"N 106°50'20.7"E        NUM  Water  47.948450  106.839092
# 7   47°55'47.1"N 106°54'29.6"E        NUM  Water  47.929758  106.908208
# 8   47°55'13.6"N 107°01'24.9"E       MUST  Water  47.920444  107.023583
# 9   47°55'48.3"N 107°00'14.0"E       MUST   Soil  47.930083  107.003889
# 10  47°56'44.7"N 106°54'49.6"E       MUST   Soil  47.945750  106.913778
# 11  47°56'33.7"N 106°54'10.5"E       MUST   Soil  47.942694  106.902917
# 12  47°56'39.2"N 106°53'18.2"E        NUM   Soil  47.944219  106.888398
# 13  47°59'58.2"N 106°47'32.9"E        NUM   Soil  47.999493  106.792462
# 14  47°56'03.2"N 106°50'26.7"E        NUM   Soil  47.934220  106.840740
# 15  47°49'39.4"N 106°40'57.4"E       MULS   Soil  47.827600  106.682600
# 16  47°53'28.3"N 106°53'31.9"E       MULS   Soil  47.891200  106.892200
# 17  47°53'47.4"N 106°45'30.2"E       MULS   Soil  47.896500  106.758400

# %%
max_tolerated_dict = {'As':20, 'Cd':3, 'Cr':150, 'Pb':100, 'Zn':300, 'Ni':150}

# %%
def make_tooltip_en(location, location_row):
    tooltip = f"""<font size="+0.5"><b>{location_row['Location'].iat[0]}</b></font><br>"""
    for date in raw_values['DATE'].unique():
        tooltip += f"{date}<br>"
        date_dict = (raw_values[(raw_values['location'] == location) & 
                                (raw_values['DATE'] == date)]
                    .to_dict(orient='records'))
        for item in date_dict:
            # If value is above tolerated level, highlight and bold
            if item['value'] > max_tolerated_dict[item['Names']]:
                tooltip += f"""<b>{metal_map_en[item['Names']]}: {item['value']} ppm</b><br>"""
            else:
                tooltip += f"{metal_map_en[item['Names']]}: {item['value']} ppm<br>"
        tooltip += "<br>"
    tooltip
    return tooltip

# %%
def make_tooltip_mn(location, location_row):
    tooltip = f"""<font size="+0.5"><b>{location_row['Location MNG'].iat[0]}</b></font><br>"""
    for date in raw_values['DATE'].unique():
        tooltip += f"{date}<br>"
        date_dict = (raw_values[(raw_values['location'] == location) & 
                                (raw_values['DATE'] == date)]
                    .to_dict(orient='records'))
        for item in date_dict:
            # If value is above tolerated level, highlight and bold
            if item['value'] > max_tolerated_dict[item['Names']]:
                tooltip += f"""<b>{metal_map_mn[item['Names']]}: {item['value']} ppm</b><br>"""
            else:
                tooltip += f"{metal_map_mn[item['Names']]}: {item['value']} ppm<br>"
        tooltip += "<br>"
    tooltip
    return tooltip

# %%
df
# Out:
#        DATE location  value        lat         lon    color
# 0   04-2022     HZS1    1.0  47.930083  107.003889  #ffff00
# 1   04-2022     HZS2    1.0  47.945750  106.913778  #ffff00
# 2   04-2022     HZS3    1.0  47.942694  106.902917  #ffff00
# 3   04-2022     HZS4    0.0  47.944219  106.888398  #878787
# 4   04-2022     HZS5    1.0  47.999493  106.792462  #ffff00
# 5   04-2022     HZS6    2.0  47.934220  106.840740  #ff7e00
# 6   04-2022     HZS7    1.0  47.827600  106.682600  #ffff00
# 7   04-2022     HZS8    3.0  47.891200  106.892200  #ff0000
# 8   04-2022     HZS9    1.0  47.896500  106.758400  #ffff00
# 9   07-2022     HZS1    0.0  47.930083  107.003889  #878787
# 10  07-2022     HZS2    0.0  47.945750  106.913778  #878787
# 11  07-2022     HZS3    0.0  47.942694  106.902917  #878787
# 12  07-2022     HZS4    0.0  47.944219  106.888398  #878787
# 13  07-2022     HZS5    0.0  47.999493  106.792462  #878787
# 14  07-2022     HZS6    2.0  47.934220  106.840740  #ff7e00
# 15  07-2022     HZS7    0.0  47.827600  106.682600  #878787
# 16  07-2022     HZS8    3.0  47.891200  106.892200  #ff0000
# 17  07-2022     HZS9    0.0  47.896500  106.758400  #878787
# 18  09-2022     HZS1    0.0  47.930083  107.003889  #878787
# 19  09-2022     HZS2    0.0  47.945750  106.913778  #878787
# 20  09-2022     HZS3    0.0  47.942694  106.902917  #878787
# 21  09-2022     HZS4    2.0  47.944219  106.888398  #ff7e00
# 22  09-2022     HZS5    0.0  47.999493  106.792462  #878787
# 23  09-2022     HZS6    0.0  47.934220  106.840740  #878787
# 24  09-2022     HZS7    0.0  47.827600  106.682600  #878787
# 25  09-2022     HZS8    2.0  47.891200  106.892200  #ff7e00
# 26  09-2022     HZS9    0.0  47.896500  106.758400  #878787

# %%
m = folium.Map([47.905776, 106.920458], 
               zoom_start=12, 
               no_touch=True, 
               #maxBounds = [[47.822221,107.151175], [47.975652,106.695092]],
               minZoom=12,
               tiles=None
    )

folium.TileLayer('https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=' + mapbox_token, 
                 name='Soil Pollution Estimates',
                 attr='Mapbox', control=False).add_to(m)

for item in locations[locations['Code'].str.contains('HZS')]['Code']:
    # Change color of dot based on pollution category
    color = df[df['location'] == 'HZS2'].nlargest(1, 'value')['color'].iloc[0]

    row = locations[locations['Code'] == item]
    tooltip = make_tooltip_en(item, row)
    folium.CircleMarker(location=[row['lat'], row['lon']], 
                       radius=3,
                       popup=folium.Popup(tooltip[:-8], parse_html=False, max_width=1000), 
                       color=color,
                       weight=7).add_to(m)

folium.LayerControl(collapsed=False, ).add_to(m)

title_html = f'''
             <h3 align="center" style="font-size:16px;">Measured soil pollution from heavy metals. Samples taken between 04-2022 and 09-2022.</h3>
             '''
m.get_root().html.add_child(folium.Element(title_html))

m.save("hazegazer_maps/soil_pollution_map_en.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = true;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2a92017544da30826458bc9d5853ede {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px;&quot;&gt;Measured soil pollution from heavy metals. Samples taken between 04-2022 and 09-2022.&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2a92017544da30826458bc9d5853ede&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f2a92017544da30826458bc9d5853ede = L.map(
#                 &quot;map_f2a92017544da30826458bc9d5853ede&quot;,
#                 {
#                     center: [47.905776, 106.920458],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     minZoom: 12,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1ee2dd1eed641ad2ecde93d4850b51d = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=pk.eyJ1Ijoicm9iZXJ0cml0eiIsImEiOiJjam01dGZtcnIxNDJhM3ZtbWZlMHFjZHc1In0.01rvohTgnLlD4VDtrQZX8g&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f2a92017544da30826458bc9d5853ede);
#
#
#             var circle_marker_35fa0415032620fe0e611d3d32107546 = L.circleMarker(
#                 [47.930083, 107.003889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_f2a92017544da30826458bc9d5853ede);
#
#
#         var popup_953129db06961b5917456a8b419f7f8a = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_b547122abe138f8dfaec5be734dcb073 = $(`&lt;div id=&quot;html_b547122abe138f8dfaec5be734dcb073&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font size=&quot;+0.5&quot;&gt;&lt;b&gt;Da Khuree zah&lt;/b&gt;&lt;/font&gt;&lt;br&gt;2022.04.01&lt;br&gt;&lt;b&gt;Arsenic: 22.0 ppm&lt;/b&gt;&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 28.0 ppm&lt;br&gt;Nickel: 13.0 ppm&lt;br&gt;Lead: 43.0 ppm&lt;br&gt;&lt;b&gt;Zinc: 443.0 ppm&lt;/b&gt;&lt;br&gt;&lt;br&gt;2022.07.01&lt;br&gt;Arsenic: 6.0 ppm&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 16.0 ppm&lt;br&gt;Nickel: 14.0 ppm&lt;br&gt;Lead: 20.0 ppm&lt;br&gt;Zinc: 71.0 ppm&lt;br&gt;&lt;br&gt;2022.09.01&lt;br&gt;Arsenic: 11.0 ppm&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 22.0 ppm&lt;br&gt;Nickel: 10.0 ppm&lt;br&gt;Lead: 51.0 ppm&lt;br&gt;Zinc: 116.0 ppm&lt;/div&gt;`)[0];
#                 popup_953129db06961b5917456a8b419f7f8a.setContent(html_b547122abe138f8dfaec5be734dcb073);
#
#
#
#         circle_marker_35fa0415032620fe0e611d3d32107546.bindPopup(popup_953129db06961b5917456a8b419f7f8a)
#         ;
#
#
#
#
#             var circle_marker_0327f7e3bbadc05ff121d1c663d09d8a = L.circleMarker(
#                 [47.94575, 106.913778],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_f2a92017544da30826458bc9d5853ede);
#
#
#         var popup_6d5bdd5ad000a00f3bcd8d57be0b8f89 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_5d9f25571ee273532c65e67f209c9796 = $(`&lt;div id=&quot;html_5d9f25571ee273532c65e67f209c9796&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font size=&quot;+0.5&quot;&gt;&lt;b&gt;3n buudal, 32 toirog&lt;/b&gt;&lt;/font&gt;&lt;br&gt;2022.04.01&lt;br&gt;&lt;b&gt;Arsenic: 22.0 ppm&lt;/b&gt;&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 32.0 ppm&lt;br&gt;Nickel: 18.0 ppm&lt;br&gt;&lt;b&gt;Lead: 346.0 ppm&lt;/b&gt;&lt;br&gt;Zinc: 283.0 ppm&lt;br&gt;&lt;br&gt;2022.07.01&lt;br&gt;Arsenic: 6.0 ppm&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 16.0 ppm&lt;br&gt;Nickel: 11.0 ppm&lt;br&gt;Lead: 29.0 ppm&lt;br&gt;Zinc: 93.0 ppm&lt;br&gt;&lt;br&gt;2022.09.01&lt;br&gt;Arsenic: 5.0 ppm&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 20.0 ppm&lt;br&gt;Nickel: 10.0 ppm&lt;br&gt;Lead: 25.0 ppm&lt;br&gt;Zinc: 97.0 ppm&lt;/div&gt;`)[0];
#                 popup_6d5bdd5ad000a00f3bcd8d57be0b8f89.setContent(html_5d9f25571ee273532c65e67f209c9796);
#
#
#
#         circle_marker_0327f7e3bbadc05ff121d1c663d09d8a.bindPopup(popup_6d5bdd5ad000a00f3bcd8d57be0b8f89)
#         ;
#
#
#
#
#             var circle_marker_76a4df05ed6022a0adfef89e1336c2bd = L.circleMarker(
#                 [47.942694, 106.902917],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;:

# %% [markdown]
# ### Mongolian

# %%
m = folium.Map([47.905776, 106.920458], 
               zoom_start=12, 
               no_touch=True, 
               #maxBounds = [[47.822221,107.151175], [47.975652,106.695092]],
               minZoom=12,
               tiles=None
    )

folium.TileLayer('https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=' + mapbox_token, 
                 name='Хөрсний бохирдлын тооцоо',
                 attr='Mapbox', control=False).add_to(m)

for item in locations[locations['Code'].str.contains('HZS')]['Code']:
    color = df[df['location'] == 'HZS2'].nlargest(1, 'value')['color'].iloc[0]

    row = locations[locations['Code'] == item]
    tooltip = make_tooltip_mn(item, row)
    folium.CircleMarker(location=[row['lat'], row['lon']], 
                       radius=3,
                       popup=folium.Popup(tooltip[:-8], parse_html=False, max_width=1000), 
                       color=color,
                       weight=7).add_to(m)

folium.LayerControl(collapsed=False, ).add_to(m)

title_html = f'''
             <h3 align="center" style="font-size:16px;">Хүнд металлын хөрсний бохирдлыг хэмжсэн. 04-2022, 09-2022 хооронд дээж авсан.</h3>
             '''
m.get_root().html.add_child(folium.Element(title_html))

m.save("hazegazer_maps/soil_pollution_map_mn.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = true;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8560384c8e517da4d9b9d2f9925d7382 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px;&quot;&gt;Хүнд металлын хөрсний бохирдлыг хэмжсэн. 04-2022, 09-2022 хооронд дээж авсан.&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8560384c8e517da4d9b9d2f9925d7382&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8560384c8e517da4d9b9d2f9925d7382 = L.map(
#                 &quot;map_8560384c8e517da4d9b9d2f9925d7382&quot;,
#                 {
#                     center: [47.905776, 106.920458],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     minZoom: 12,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e957ab6089874283e56db4146b75380a = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=pk.eyJ1Ijoicm9iZXJ0cml0eiIsImEiOiJjam01dGZtcnIxNDJhM3ZtbWZlMHFjZHc1In0.01rvohTgnLlD4VDtrQZX8g&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8560384c8e517da4d9b9d2f9925d7382);
#
#
#             var circle_marker_83879c95a5d0087da613cde5e2defefa = L.circleMarker(
#                 [47.930083, 107.003889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_8560384c8e517da4d9b9d2f9925d7382);
#
#
#         var popup_fe3c66f56a9300fe386b06852b2f1fca = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_aefff877078907fcd5d12a4cbd916888 = $(`&lt;div id=&quot;html_aefff877078907fcd5d12a4cbd916888&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font size=&quot;+0.5&quot;&gt;&lt;b&gt;Да Хүрээ&lt;/b&gt;&lt;/font&gt;&lt;br&gt;2022.04.01&lt;br&gt;&lt;b&gt;Хүнцэл: 22.0 ppm&lt;/b&gt;&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 28.0 ppm&lt;br&gt;Никель: 13.0 ppm&lt;br&gt;Тэргүүлэх: 43.0 ppm&lt;br&gt;&lt;b&gt;Цайр: 443.0 ppm&lt;/b&gt;&lt;br&gt;&lt;br&gt;2022.07.01&lt;br&gt;Хүнцэл: 6.0 ppm&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 16.0 ppm&lt;br&gt;Никель: 14.0 ppm&lt;br&gt;Тэргүүлэх: 20.0 ppm&lt;br&gt;Цайр: 71.0 ppm&lt;br&gt;&lt;br&gt;2022.09.01&lt;br&gt;Хүнцэл: 11.0 ppm&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 22.0 ppm&lt;br&gt;Никель: 10.0 ppm&lt;br&gt;Тэргүүлэх: 51.0 ppm&lt;br&gt;Цайр: 116.0 ppm&lt;/div&gt;`)[0];
#                 popup_fe3c66f56a9300fe386b06852b2f1fca.setContent(html_aefff877078907fcd5d12a4cbd916888);
#
#
#
#         circle_marker_83879c95a5d0087da613cde5e2defefa.bindPopup(popup_fe3c66f56a9300fe386b06852b2f1fca)
#         ;
#
#
#
#
#             var circle_marker_ea064e8d4b187ee543c84967075efa32 = L.circleMarker(
#                 [47.94575, 106.913778],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_8560384c8e517da4d9b9d2f9925d7382);
#
#
#         var popup_3c4ece4f75b10a9af9b750ca07b9ac0e = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_823ed8bc1b0689a67dcc6a8c0ed4bf29 = $(`&lt;div id=&quot;html_823ed8bc1b0689a67dcc6a8c0ed4bf29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font size=&quot;+0.5&quot;&gt;&lt;b&gt;3-н буудал, 32-н тойрог&lt;/b&gt;&lt;/font&gt;&lt;br&gt;2022.04.01&lt;br&gt;&lt;b&gt;Хүнцэл: 22.0 ppm&lt;/b&gt;&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 32.0 ppm&lt;br&gt;Никель: 18.0 ppm&lt;br&gt;&lt;b&gt;Тэргүүлэх: 346.0 ppm&lt;/b&gt;&lt;br&gt;Цайр: 283.0 ppm&lt;br&gt;&lt;br&gt;2022.07.01&lt;br&gt;Хүнцэл: 6.0 ppm&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 16.0 ppm&lt;br&gt;Никель: 11.0 ppm&lt;br&gt;Тэргүүлэх: 29.0 ppm&lt;br&gt;Цайр: 93.0 ppm&lt;br&gt;&lt;br&gt;2022.09.01&lt;br&gt;Хүнцэл: 5.0 ppm&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 20.0 ppm&lt;br&gt;Никель: 10.0 ppm&lt;br&gt;Тэргүүлэх: 25.0 ppm&lt;br&gt;Цайр: 97.0 ppm&lt;/div&gt;`)[0];
#                 popup_3c4ece4f75b10a9af9b750ca07b9ac0e.setContent(html_823ed8bc1b0689a67dcc6a8c0ed4bf29);
#
#
#
#         circle_marker_ea064e8d4b187ee543c84967075efa32.bindPopup(popup_3c4ece4f75b10a9af9b750ca07b9ac0e)
#         ;
#
#
#
#
#             var circle_marker_b72004f998060745f87365627d028145 = L.circleMarker(
#                 [47.942694, 106.902917],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffse

# %% [markdown]
# ## Push to Github

# %%
# !git -C hazegazer_maps pull
# Out:
# From https://github.com/robertritz/hazegazer_maps
#    6445c80..a1e912a  main       -> origin/main
# Already up to date.

# %%
# !git config --global user.name "Robert Ritz"
# !git config --global user.email robertritz@outlook.com

# %%
today = datetime.datetime.today().strftime("%Y-%m-%d")

# !git -C hazegazer_maps add --all
# !git -C hazegazer_maps commit -m 'Pushed new map - {today}'
# Out:
# [main 271fc1e] Pushed new map - 2023-01-18
#  2 files changed, 128 insertions(+), 128 deletions(-)

# %%
repo_url = f'https://{github_username}:{github_key}@github.com/robertritz/hazegazer_maps.git'

# !git -C hazegazer_maps push {repo_url}
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 2.67 KiB | 2.67 MiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/robertritz/hazegazer_maps.git
#    a1e912a..271fc1e  main -> main

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ba114c06-219e-428f-aac8-ac1509227acf' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
