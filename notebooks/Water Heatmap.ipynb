# %% [markdown]
# # Water Map Creation

# %% [markdown]
# This notebook creates a heatmap showing heavy metal soil pollution in Ulaanbaatar, Mongolia. Data were collected in April/July 2022 by faculty and students from the Mongolian National University and the Mongolian University of Science and Technology.

# %% [markdown]
# Many tests were performed on the soil samples collected, and this analysis focuses on the most harmful heavy metals. Mongolia, via [MNS4586:1998](https://estandard.gov.mn/standard/reader/3394), sets standards on harful and dangerous levels of many heavy metals. Those levels are:
#
# | Metal        | Unit    | Maximum Tolerated |
# | ------------ | ---- | -------- |
# | Arsenic (As) | ppm  | 0.01       |
# | Cadmium (Cd) | ppm  | 0.005        |
# | Chromium (Cr) | ppm  | 0.05        |
# | Lead (Pb)    | ppm  | 0.01      |
# | Zinc (Zn)    | ppm  | 0.01      |
# | Nickel (Ni)  | ppm  | 0.01      |

# %%
import pandas as pd
import numpy as np
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern
from sklearn.gaussian_process.kernels import RBF

import psycopg2
import sqlalchemy as db

import datetime
import os

import plotly.graph_objects as go
import folium
from folium.plugins import FeatureGroupSubGroup

# %%
mapbox_token = os.environ["MAPBOX_TOKEN"]
github_username = os.environ["GITHUB_USERNAME"]
github_key = os.environ["GITHUB_KEY"]

# %%
locations = pd.read_csv("locations.csv")
df = pd.read_csv("data/Water and Soil Combined.csv")

# %%
metals = ['As','Cd','Cr','Pb','Zn','Ni']
df = df[df['Names'].isin(metals)]

# %%
df['Names'].unique()
# Out:
# array(['As', 'Cd', 'Cr', 'Ni', 'Pb', 'Zn'], dtype=object)

# %%
df = df.drop(columns=['METHOD','LDETECTION','UDETECTION'])

# %% [markdown]
# The water pollutants are measured in PPB while the soil ones are measured in PPM.

# %%
df = df.melt(id_vars=['DATE','Names','UNITS'], var_name='location')

# %%
df = df.dropna()

# %%
df['Names'].unique()
# Out:
# array(['As', 'Cd', 'Cr', 'Ni', 'Pb', 'Zn'], dtype=object)

# %%
df.loc[df['value'].str.contains("<"), 'value'] = 0

# %%
df['value'] = df['value'].astype('float')

# %%
df = df[df['location'].str.contains("HZW")]

# %% [markdown]
# Convert PPB to mg/L (which is approximately PPM).

# %%
df['value'] = df['value'] / 1000

# %%
df = df.drop(columns='UNITS')

# %% [markdown]
# Group by location and date.

# %%
df = df.groupby(by=['Names', 'location', 'DATE']).mean().reset_index()

# %%
df['location'] = df['location'].str.replace("-","")

# %%
locations['lat'] = locations['Decimal Degrees (DD)'].str.split(", ").str.get(0).astype('float')
locations['lon'] = locations['Decimal Degrees (DD)'].str.split(", ").str.get(1).astype('float')

# %%
df = df.merge(locations[['Code','lat','lon']], how='left', left_on='location', right_on='Code')

# %%
raw_values = df.copy()

# %% [markdown]
# ## Make cuts

# %% [markdown]
# | Metal        | Unit    | Maximum Tolerated |
# | ------------ | ---- | -------- |
# | Arsenic (As) | ppm  | 0.01       |
# | Cadmium (Cd) | ppm  | 0.005        |
# | Chromium (Cr) | ppm  | 0.05        |
# | Lead (Pb)    | ppm  | 0.01      |
# | Zinc (Zn)    | ppm  | 0.01      |
# | Nickel (Ni)  | ppm  | 0.01      |

# %%
as_bins = [0, 0.01, 10000]
cd_bins = [0, 0.005, 10000]
cr_bins = [0, 0.05, 10000]
pb_bins = [0, 0.01, 10000]
zn_bins = [0, 0.01, 10000]
ni_bins = [0, 0.01, 10000]

# %%
df.loc[df['Names'] == 'As', 'value'] = pd.cut(df[df['Names'] == 'As']['value'], as_bins, labels=False, include_lowest=True)
df.loc[df['Names'] == 'Cd', 'value'] = pd.cut(df[df['Names'] == 'Cd']['value'], cd_bins, labels=False, include_lowest=True)
df.loc[df['Names'] == 'Cr', 'value'] = pd.cut(df[df['Names'] == 'Cr']['value'], cr_bins, labels=False, include_lowest=True)
df.loc[df['Names'] == 'Pb', 'value'] = pd.cut(df[df['Names'] == 'Pb']['value'], pb_bins, labels=False, include_lowest=True)
df.loc[df['Names'] == 'Zn', 'value'] = pd.cut(df[df['Names'] == 'Zn']['value'], zn_bins, labels=False, include_lowest=True)
df.loc[df['Names'] == 'Ni', 'value'] = pd.cut(df[df['Names'] == 'Ni']['value'], ni_bins, labels=False, include_lowest=True)

# %% [markdown]
# Similar to AQI, we will take the maximum value for each heavy metal. This will be our toxicity level. After all, a dangerous level of only one heavy metal is dangerous. Averaging the levels will only reduce the actual, which would not make sense.

# %%
df = df.groupby(by=['DATE', 'location']).max().reset_index().drop(columns=['Names','Code'])

# %%
df
# Out:
#           DATE location  value        lat         lon
# 0   2022.04.01     HZW1    0.0  47.914410  106.830080
# 1   2022.04.01     HZW2    0.0  47.873160  106.784480
# 2   2022.04.01     HZW3    1.0  47.890600  106.734900
# 3   2022.04.01     HZW4    0.0  47.848400  106.676100
# 4   2022.04.01     HZW5    0.0  47.925750  106.931500
# 5   2022.04.01     HZW6    0.0  47.942462  106.927077
# 6   2022.04.01     HZW7    0.0  47.948450  106.839092
# 7   2022.04.01     HZW8    0.0  47.929758  106.908208
# 8   2022.04.01     HZW9    0.0  47.920444  107.023583
# 9   2022.07.01     HZW1    1.0  47.914410  106.830080
# 10  2022.07.01     HZW5    0.0  47.925750  106.931500
# 11  2022.07.01     HZW6    0.0  47.942462  106.927077
# 12  2022.07.01     HZW7    1.0  47.948450  106.839092
# 13  2022.07.01     HZW8    1.0  47.929758  106.908208
# 14  2022.07.01     HZW9    0.0  47.920444  107.023583
# 15  2022.09.01     HZW1    0.0  47.914410  106.830080
# 16  2022.09.01     HZW2    0.0  47.873160  106.784480
# 17  2022.09.01     HZW3    0.0  47.890600  106.734900
# 18  2022.09.01     HZW4    0.0  47.848400  106.676100
# 19  2022.09.01     HZW5    0.0  47.925750  106.931500
# 20  2022.09.01     HZW6    0.0  47.942462  106.927077
# 21  2022.09.01     HZW7    1.0  47.948450  106.839092
# 22  2022.09.01     HZW8    1.0  47.929758  106.908208

# %% [markdown]
# ## Map Code

# %% [markdown]
# ### English

# %% [markdown]
# New strategy, combine all heavy metals into one heatmap and then make a new layer for each time period (April, July, September). Call it heavy metal pollution in soil and water.

# %%
df['DATE'] = pd.to_datetime(df['DATE']).dt.strftime("%m-%Y")

# %%
raw_values['DATE'] = pd.to_datetime(raw_values['DATE']).dt.strftime("%m-%Y")

# %%
locations[locations['Code'].str.contains('HZS')]['Code']
# Out:
# 9     HZS1
# 10    HZS2
# 11    HZS3
# 12    HZS4
# 13    HZS5
# 14    HZS6
# 15    HZS7
# 16    HZS8
# 17    HZS9
# Name: Code, dtype: object

# %%
raw_values['DATE'].unique()
# Out:
# array(['04-2022', '07-2022', '09-2022'], dtype=object)

# %%
raw_values['value'] = raw_values['value'].round(3)

# %%
metal_map_en = {'As':'Arsenic','Cd':'Cadmium','Cr':'Chromium','Pb':'Lead','Zn':'Zinc','Ni':'Nickel'}
metal_map_mn = {'As':'Хүнцэл','Cd':'Кадми','Cr':'Хром','Pb':'Тэргүүлэх','Zn':'Цайр','Ni':'Никель'}

# %%
as_bins = [0, 0.01, 10000]
cd_bins = [0, 0.005, 10000]
cr_bins = [0, 0.05, 10000]
pb_bins = [0, 0.01, 10000]
zn_bins = [0, 0.01, 10000]
ni_bins = [0, 0.01, 10000]

# %%
max_tolerated_dict = {'As':0.01, 'Cd':0.005, 'Cr':0.05, 'Pb':0.01, 'Zn':0.01, 'Ni':0.01}

# %%
def make_tooltip_en(location, location_row):
    tooltip = f"""<font size="+0.5"><b>{location_row['Location'].iat[0]}</b></font><br>"""
    for date in raw_values['DATE'].unique():
        tooltip += f"{date}<br>"
        date_dict = (raw_values[(raw_values['location'] == location) & 
                                (raw_values['DATE'] == date)]
                    .to_dict(orient='records'))
        for item in date_dict:
            # If value is above tolerated level, highlight and bold
            if item['value'] > max_tolerated_dict[item['Names']]:
                tooltip += f"""<b>{metal_map_en[item['Names']]}: {item['value']} ppm</b><br>"""
            else:
                tooltip += f"{metal_map_en[item['Names']]}: {item['value']} ppm<br>"
        tooltip += "<br>"
    tooltip
    return tooltip

# %%
def make_tooltip_mn(location, location_row):
    tooltip = f"""<font size="+0.5"><b>{location_row['Location MNG'].iat[0]}</b></font><br>"""
    for date in raw_values['DATE'].unique():
        tooltip += f"{date}<br>"
        date_dict = (raw_values[(raw_values['location'] == location) & 
                                (raw_values['DATE'] == date)]
                    .to_dict(orient='records'))
        for item in date_dict:
            # If value is above tolerated level, highlight and bold
            if item['value'] > max_tolerated_dict[item['Names']]:
                tooltip += f"""<b>{metal_map_mn[item['Names']]}: {item['value']} ppm</b><br>"""
            else:
                tooltip += f"{metal_map_mn[item['Names']]}: {item['value']} ppm<br>"
        tooltip += "<br>"
    tooltip
    return tooltip

# %%
locations
# Out:
#     Code                            Location  \
# 0   HZW1  1-r horoollin hurin us hayah suvag
# 1   HZW2                  Sonsgolongiin guur
# 2   HZW3        TTsB-iin hayagdal usni suvag
# 3   HZW4                  Biokombinatin guur
# 4   HZW5                          Zuun Selbe
# 5   HZW6                        32-in toirog
# 6   HZW7                     Nuden nuur SKHD
# 7   HZW8                         Nogoon nuur
# 8   HZW9                        Uliastai gol
# 9   HZS1                       Da Khuree zah
# 10  HZS2                3n buudal, 32 toirog
# 11  HZS3                    Denjiin 1000 zah
# 12  HZS4                           70 davhar
# 13  HZS5                       Ulaan chuluut
# 14  HZS6                     SKHD 7-r khoroo
# 15  HZS7          Biokombinatin khogiin tseg
# 16  HZS8             Khargia TSB iin khashaa
# 17  HZS9                   TS4-iin unsen san
#
#                                      Location MNG   Decimal Degrees (DD)  \
# 0               1-р хорооллын хурын ус хаях суваг    47.91441, 106.83008
# 1                              Сонсголонгийн гүүр    47.87316, 106.78448
# 2   Төв цэвэрлэх байгууламжийн хаягдал усны суваг      47.8906, 106.7349
# 3                              Биокомбинатын гүүр      47.8484, 106.6761
# 4                                      Зүүн Сэлбэ  47.925750, 106.931500
# 5                                     32-н тойрог  47.942462, 106.927077
# 6                                  Нүдэн нуур СХД   47.94845, 106.839092
# 7                                     Ногоон нуур  47.929758, 106.908208
# 8                                    Улиастай гол  47.920444, 107.023583
# 9                                        Да Хүрээ  47.930083, 107.003889
# 10                        3-н буудал, 32-н тойрог  47.945750, 106.913778
# 11                             Дэнжийн 1000-н зах  47.942694, 106.902917
# 12                                      70 давхар  47.944219, 106.888398
# 13                                   Улаан чулуут  47.999493, 106.792462
# 14                                   СХД 7- хороо  47.934220, 106.840740
# 15                       Биокомбинатын хогийн цэг      47.8276, 106.6826
# 16                            Харгиа ЦБ-ийн хашаа      47.8912, 106.8922
# 17                             ТЭЦ4-ийн үнсэн сан      47.8965, 106.7584
#
#       Degrees, min, secs (DMS) University Sample        lat         lon
# 0   47°54'51.9"N 106°49'48.3"E       MUST  Water  47.914410  106.830080
# 1   47°52'23.4"N 106°47'04.1"E       MULS  Water  47.873160  106.784480
# 2   47°53'26.2"N 106°44'05.6"E       MULS  Water  47.890600  106.734900
# 3   47°50'54.2"N 106°40'34.0"E       MULS  Water  47.848400  106.676100
# 4   47°55'32.7"N 106°55'53.4"E       MUST  Water  47.925750  106.931500
# 5   47°56'32.9"N 106°55'37.5"E        NUM  Water  47.942462  106.927077
# 6   47°56'54.4"N 106°50'20.7"E        NUM  Water  47.948450  106.839092
# 7   47°55'47.1"N 106°54'29.6"E        NUM  Water  47.929758  106.908208
# 8   47°55'13.6"N 107°01'24.9"E       MUST  Water  47.920444  107.023583
# 9   47°55'48.3"N 107°00'14.0"E       MUST   Soil  47.930083  107.003889
# 10  47°56'44.7"N 106°54'49.6"E       MUST   Soil  47.945750  106.913778
# 11  47°56'33.7"N 106°54'10.5"E       MUST   Soil  47.942694  106.902917
# 12  47°56'39.2"N 106°53'18.2"E        NUM   Soil  47.944219  106.888398
# 13  47°59'58.2"N 106°47'32.9"E        NUM   Soil  47.999493  106.792462
# 14  47°56'03.2"N 106°50'26.7"E        NUM   Soil  47.934220  106.840740
# 15  47°49'39.4"N 106°40'57.4"E       MULS   Soil  47.827600  106.682600
# 16  47°53'28.3"N 106°53'31.9"E       MULS   Soil  47.891200  106.892200
# 17  47°53'47.4"N 106°45'30.2"E       MULS   Soil  47.896500  106.758400

# %%
m = folium.Map([47.905776, 106.900458],
               zoom_start=12, 
               no_touch=True, 
               #maxBounds = [[48.0060304,106.8112538], [47.9179387,107.0480388]],
               minZoom=12,
               tiles=None
    )

folium.TileLayer('https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=' + mapbox_token, 
                 name='Water Pollution Estimates',
                 attr='Mapbox', control=False).add_to(m)

for location in locations[locations['Code'].str.contains('HZW')]['Code']:
    if df[df['location'] == location]['value'].max() > 0:
        color = '#ffff00'
    else:
        color = '#878787'

    row = locations[locations['Code'] == location]
    tooltip = make_tooltip_en(location, row)

    folium.CircleMarker(location=[row['lat'], row['lon']], 
                       radius=3,
                       popup=folium.Popup(tooltip[:-8], parse_html=False, max_width=1000), 
                       color=color,
                       weight=7).add_to(m)

title_html = f'''
             <h3 align="center" style="font-size:16px;">Measured water pollution from heavy metals. Samples taken between 04-2022 and 09-2022.</h3>
             '''
m.get_root().html.add_child(folium.Element(title_html))

m.save("hazegazer_maps/water_pollution_map_en.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = true;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69003101313a3ae2700b97e23d76a63d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px;&quot;&gt;Measured water pollution from heavy metals. Samples taken between 04-2022 and 09-2022.&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69003101313a3ae2700b97e23d76a63d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_69003101313a3ae2700b97e23d76a63d = L.map(
#                 &quot;map_69003101313a3ae2700b97e23d76a63d&quot;,
#                 {
#                     center: [47.905776, 106.900458],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     minZoom: 12,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_708a495685481694aa872fab775e9b93 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=pk.eyJ1Ijoicm9iZXJ0cml0eiIsImEiOiJjam01dGZtcnIxNDJhM3ZtbWZlMHFjZHc1In0.01rvohTgnLlD4VDtrQZX8g&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_69003101313a3ae2700b97e23d76a63d);
#
#
#             var circle_marker_a683b87773db9ee5dab22ec543e1dc8d = L.circleMarker(
#                 [47.91441, 106.83008],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_69003101313a3ae2700b97e23d76a63d);
#
#
#         var popup_ac19a7f9d914a207f243ea68b9cb1138 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_7a382123285b76de32f07eb1c2fa240c = $(`&lt;div id=&quot;html_7a382123285b76de32f07eb1c2fa240c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font size=&quot;+0.5&quot;&gt;&lt;b&gt;1-r horoollin hurin us hayah suvag&lt;/b&gt;&lt;/font&gt;&lt;br&gt;04-2022&lt;br&gt;Arsenic: 0.003 ppm&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 0.0 ppm&lt;br&gt;Nickel: 0.001 ppm&lt;br&gt;Lead: 0.0 ppm&lt;br&gt;Zinc: 0.0 ppm&lt;br&gt;&lt;br&gt;07-2022&lt;br&gt;Arsenic: 0.003 ppm&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 0.0 ppm&lt;br&gt;&lt;b&gt;Nickel: 0.019 ppm&lt;/b&gt;&lt;br&gt;Lead: 0.0 ppm&lt;br&gt;Zinc: 0.0 ppm&lt;br&gt;&lt;br&gt;09-2022&lt;br&gt;Arsenic: 0.005 ppm&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 0.0 ppm&lt;br&gt;Nickel: 0.006 ppm&lt;br&gt;Lead: 0.001 ppm&lt;br&gt;Zinc: 0.0 ppm&lt;/div&gt;`)[0];
#                 popup_ac19a7f9d914a207f243ea68b9cb1138.setContent(html_7a382123285b76de32f07eb1c2fa240c);
#
#
#
#         circle_marker_a683b87773db9ee5dab22ec543e1dc8d.bindPopup(popup_ac19a7f9d914a207f243ea68b9cb1138)
#         ;
#
#
#
#
#             var circle_marker_28c800250a0b5c2a9d6b9583083ccc2a = L.circleMarker(
#                 [47.87316, 106.78448],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#878787&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#878787&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_69003101313a3ae2700b97e23d76a63d);
#
#
#         var popup_5035dcc72379d93cb28b9177572d739c = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_d7fb684a7c3a7ebf45483139e6a330a3 = $(`&lt;div id=&quot;html_d7fb684a7c3a7ebf45483139e6a330a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font size=&quot;+0.5&quot;&gt;&lt;b&gt;Sonsgolongiin guur&lt;/b&gt;&lt;/font&gt;&lt;br&gt;04-2022&lt;br&gt;Arsenic: 0.0 ppm&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 0.0 ppm&lt;br&gt;Nickel: 0.0 ppm&lt;br&gt;Lead: 0.0 ppm&lt;br&gt;Zinc: 0.0 ppm&lt;br&gt;&lt;br&gt;07-2022&lt;br&gt;&lt;br&gt;09-2022&lt;br&gt;Arsenic: 0.001 ppm&lt;br&gt;Cadmium: 0.0 ppm&lt;br&gt;Chromium: 0.0 ppm&lt;br&gt;Nickel: 0.0 ppm&lt;br&gt;Lead: 0.0 ppm&lt;br&gt;Zinc: 0.0 ppm&lt;/div&gt;`)[0];
#                 popup_5035dcc72379d93cb28b9177572d739c.setContent(html_d7fb684a7c3a7ebf45483139e6a330a3);
#
#
#
#         circle_marker_28c800250a0b5c2a9d6b9583083ccc2a.bindPopup(popup_5035dcc72379d93cb28b9177572d739c)
#         ;
#
#
#
#
#             var circle_marker_e60d7409e82198b7c3cb6cb76793ef11 = L.circleMarker(
#                 [47.8906, 106.7349],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;li

# %% [markdown]
# ### Mongolian

# %%
m = folium.Map([47.905776, 106.900458],
               zoom_start=12, 
               no_touch=True, 
               #maxBounds = [[48.0060304,106.8112538], [47.9179387,107.0480388]],
               minZoom=12,
               tiles=None
    )

folium.TileLayer('https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=' + mapbox_token, 
                 name='Усны бохирдлын тооцоо',
                 attr='Mapbox', control=False).add_to(m)

for location in locations[locations['Code'].str.contains('HZW')]['Code']:
    if df[df['location'] == location]['value'].max() > 0:
        color = '#ffff00'
    else:
        color = '#878787'

    row = locations[locations['Code'] == location]
    tooltip = make_tooltip_mn(location, row)

    folium.CircleMarker(location=[row['lat'], row['lon']], 
                       radius=3,
                       popup=folium.Popup(tooltip[:-8], parse_html=False, max_width=1000), 
                       color=color,
                       weight=7).add_to(m)

title_html = f'''
             <h3 align="center" style="font-size:16px;">Хүнд металлын усны бохирдлыг хэмжсэн. 04-2022, 09-2022 хооронд дээж авсан.</h3>
             '''
m.get_root().html.add_child(folium.Element(title_html))

m.save("hazegazer_maps/water_pollution_map_mn.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = true;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8251c0fe4d25e24d83d6669d5d19bed7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px;&quot;&gt;Хүнд металлын усны бохирдлыг хэмжсэн. 04-2022, 09-2022 хооронд дээж авсан.&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8251c0fe4d25e24d83d6669d5d19bed7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8251c0fe4d25e24d83d6669d5d19bed7 = L.map(
#                 &quot;map_8251c0fe4d25e24d83d6669d5d19bed7&quot;,
#                 {
#                     center: [47.905776, 106.900458],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     minZoom: 12,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46add59c76e775c126107bae9a1c5a0b = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=pk.eyJ1Ijoicm9iZXJ0cml0eiIsImEiOiJjam01dGZtcnIxNDJhM3ZtbWZlMHFjZHc1In0.01rvohTgnLlD4VDtrQZX8g&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8251c0fe4d25e24d83d6669d5d19bed7);
#
#
#             var circle_marker_e0cc49f4aa9588cf3e4fbf349d7436dc = L.circleMarker(
#                 [47.91441, 106.83008],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_8251c0fe4d25e24d83d6669d5d19bed7);
#
#
#         var popup_8810239a28d33838420c2eb27cfb6f39 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_ece28c498eb61c827f9ca16058c04a33 = $(`&lt;div id=&quot;html_ece28c498eb61c827f9ca16058c04a33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font size=&quot;+0.5&quot;&gt;&lt;b&gt;1-р хорооллын хурын ус хаях суваг&lt;/b&gt;&lt;/font&gt;&lt;br&gt;04-2022&lt;br&gt;Хүнцэл: 0.003 ppm&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 0.0 ppm&lt;br&gt;Никель: 0.001 ppm&lt;br&gt;Тэргүүлэх: 0.0 ppm&lt;br&gt;Цайр: 0.0 ppm&lt;br&gt;&lt;br&gt;07-2022&lt;br&gt;Хүнцэл: 0.003 ppm&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 0.0 ppm&lt;br&gt;&lt;b&gt;Никель: 0.019 ppm&lt;/b&gt;&lt;br&gt;Тэргүүлэх: 0.0 ppm&lt;br&gt;Цайр: 0.0 ppm&lt;br&gt;&lt;br&gt;09-2022&lt;br&gt;Хүнцэл: 0.005 ppm&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 0.0 ppm&lt;br&gt;Никель: 0.006 ppm&lt;br&gt;Тэргүүлэх: 0.001 ppm&lt;br&gt;Цайр: 0.0 ppm&lt;/div&gt;`)[0];
#                 popup_8810239a28d33838420c2eb27cfb6f39.setContent(html_ece28c498eb61c827f9ca16058c04a33);
#
#
#
#         circle_marker_e0cc49f4aa9588cf3e4fbf349d7436dc.bindPopup(popup_8810239a28d33838420c2eb27cfb6f39)
#         ;
#
#
#
#
#             var circle_marker_6e59bfe6c923ad3cb46e0ce42912d102 = L.circleMarker(
#                 [47.87316, 106.78448],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#878787&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#878787&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_8251c0fe4d25e24d83d6669d5d19bed7);
#
#
#         var popup_6788be2dca926a6efb926b6a1dd5a773 = L.popup({&quot;maxWidth&quot;: 1000});
#
#
#
#                 var html_03e4cf6aef27f08d44d8095d1b065c82 = $(`&lt;div id=&quot;html_03e4cf6aef27f08d44d8095d1b065c82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font size=&quot;+0.5&quot;&gt;&lt;b&gt;Сонсголонгийн гүүр&lt;/b&gt;&lt;/font&gt;&lt;br&gt;04-2022&lt;br&gt;Хүнцэл: 0.0 ppm&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 0.0 ppm&lt;br&gt;Никель: 0.0 ppm&lt;br&gt;Тэргүүлэх: 0.0 ppm&lt;br&gt;Цайр: 0.0 ppm&lt;br&gt;&lt;br&gt;07-2022&lt;br&gt;&lt;br&gt;09-2022&lt;br&gt;Хүнцэл: 0.001 ppm&lt;br&gt;Кадми: 0.0 ppm&lt;br&gt;Хром: 0.0 ppm&lt;br&gt;Никель: 0.0 ppm&lt;br&gt;Тэргүүлэх: 0.0 ppm&lt;br&gt;Цайр: 0.0 ppm&lt;/div&gt;`)[0];
#                 popup_6788be2dca926a6efb926b6a1dd5a773.setContent(html_03e4cf6aef27f08d44d8095d1b065c82);
#
#
#
#         circle_marker_6e59bfe6c923ad3cb46e0ce42912d102.bindPopup(popup_6788be2dca926a6efb926b6a1dd5a773)
#         ;
#
#
#
#
#             var circle_marker_faf23738eade28f9fe272900f59cf4f7 = L.circleMarker(
#                 [47.8906, 106.7349],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;rou

# %% [markdown]
# ## Push to Github

# %%
# !git -C hazegazer_maps pull
# Out:
# From https://github.com/robertritz/hazegazer_maps
#    020aa06..6445c80  main       -> origin/main
# Already up to date.

# %%
# !git config --global user.name "Robert Ritz"
# !git config --global user.email robertritz@outlook.com

# %%
today = datetime.datetime.today().strftime("%Y-%m-%d")

# !git -C hazegazer_maps add --all
# !git -C hazegazer_maps commit -m 'Pushed new map - {today}'
# Out:
# [main a1e912a] Pushed new map - 2023-01-18
#  2 files changed, 130 insertions(+), 130 deletions(-)

# %%
repo_url = f'https://{github_username}:{github_key}@github.com/robertritz/hazegazer_maps.git'

# !git -C hazegazer_maps push {repo_url}
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 2.79 KiB | 2.79 MiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/robertritz/hazegazer_maps.git
#    6445c80..a1e912a  main -> main

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ba114c06-219e-428f-aac8-ac1509227acf' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
