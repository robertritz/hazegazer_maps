# %% [markdown]
# # Pollution Heatmap Creation

# %% [markdown]
# This script is designed to be run once every 24 hours. It will:
#
# - Pull the last 7 days of PM2.5 pollution data from the Mongol.ai air quality database. All values computed are in the Mongolian AQI standard.
# - Calculate 7 day averages on a per station basis.
# - If a station is missing more than half of the expected measurements (24\*7 = 168/2 = 84) it will be removed from usage on the heatmap for that month.
#
# The output will be a grid of pollution values from 0-5 according to the Mongolian AQI standard as follows:
#
# | AQI_MN Value | Category Name                           | Resulting Cat |
# |--------------|-----------------------------------------|---------------|
# | 0-50         | Цэвэр (Clean)                           | 0             |
# | 51-100       | Хэвийн (Normal)                         | 1             |
# | 101-200      | Бага бохирдолтой (Low Pollution)        | 2             |
# | 201-300      | Бохирдолтой (Polluted)                  | 3             |
# | 301-400      | Их бохирдолтой (Very Polluted)          | 4             |
# | 401-500      | Маш их бохирдолтой (Extremely Polluted) | 5             |

# %%
import pandas as pd
import numpy as np
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern

import psycopg2
import sqlalchemy as db

import datetime
import os

import plotly.graph_objects as go
import folium
import branca.colormap as cm

# %%
conn_string = os.environ["DB_STRING"]
mapbox_token = os.environ["MAPBOX_TOKEN"]
github_username = os.environ["GITHUB_USERNAME"]
github_key = os.environ["GITHUB_KEY"]

# %%
engine = db.create_engine(conn_string)

# %% [markdown]
# ## Pull 7 Days of PM2.5 Data

# %%
start_date = (datetime.datetime.today() - datetime.timedelta(days=7)).strftime("%Y-%m-%d")
end_date = datetime.datetime.today().strftime("%Y-%m-%d")

# %%
start_date
# Out:
# '2023-04-20'

# %%
#start_date = '2020-01-01'
#end_date = '2020-01-30'

# %%
query = f"""
    select
        *
    from
        master
    where
        "type" = 'PM2.5'
        and "date" >= '{start_date}'
        and "date" <= '{end_date}'
        and ("source" = 'Stateair.mn'
            or "source" = 'Agaar.mn');
    """
df = pd.read_sql(query, engine)
df['aqi_mn'] = df['aqi_mn'].astype('float')
df['lat'] = df['lat'].astype('float')
df['lon'] = df['lon'].astype('float')

# %%
df[df['type'] == 'PM2.5']['station_mn'].unique()
# Out:
# array(['АНУ-ын Элчин сайдын яам', 'Эрдэнэт Хаядлын сан', 'Баянхошуу',
#        'Эрдэнэт 2-р цэцэрлэг', 'Дамбадаржаа', '1-р хороолол', 'Хайлааст',
#        'Налайх', 'Богд хааны ордон музей', 'Амгалан', 'МҮОНРТ', 'Толгойт',
#        'Нисэх', 'Бөхийн өргөө', 'Баруун 4 зам'], dtype=object)

# %%
df.tail()
# Out:
#             lat         lon   type    source  aqi_mn   unit  \
# 2463  47.777195  107.252640  PM2.5  Agaar.mn    14.0  µg/m3
# 2464  47.896942  106.906390  PM2.5  Agaar.mn     7.0  µg/m3
# 2465  47.913430  106.997910  PM2.5  Agaar.mn    47.0  µg/m3
# 2466  47.929733  106.888626  PM2.5  Agaar.mn    43.0  µg/m3
# 2467  47.922497  106.794810  PM2.5  Agaar.mn    15.0  µg/m3
#
#                      date  station              station_mn  aqi_us  value
# 2463  2023-04-22 22:00:00     None                  Налайх     NaN   10.0
# 2464  2023-04-22 22:00:00     None  Богд хааны ордон музей     NaN    5.0
# 2465  2023-04-22 22:00:00  Amgalan                 Амгалан     NaN   33.0
# 2466  2023-04-22 22:00:00      MNB                  МҮОНРТ     NaN   30.0
# 2467  2023-04-22 22:00:00  Tolgoit                 Толгойт     NaN   10.0

# %% [markdown]
# Remove stations with less than the 84 required measurements for 1 week. We will first count the number of records per station per PM type, then filter out (using .loc) on the df.

# %%
df = df.dropna(subset=['aqi_mn'])
df_count = df.groupby(by=['type','station_mn']).count().reset_index()
stations = df_count[df_count['aqi_mn'] > 84][['type','station_mn']].reset_index(drop=True)
avg = df.groupby(by=['type','station_mn']).mean().loc[stations.to_records(index=False).tolist()].reset_index()

# %%
df_count
# Out:
#      type               station_mn  lat  lon  source  aqi_mn  unit  date  \
# 0   PM2.5             1-р хороолол  168  168     168     168   168   168
# 1   PM2.5  АНУ-ын Элчин сайдын яам  144  144     144     144   144   144
# 2   PM2.5                  Амгалан  168  168     168     168   168   168
# 3   PM2.5             Баруун 4 зам  168  168     168     168   168   168
# 4   PM2.5                Баянхошуу  125  125     125     125   125   125
# 5   PM2.5   Богд хааны ордон музей  167  167     167     167   167   167
# 6   PM2.5             Бөхийн өргөө  168  168     168     168   168   168
# 7   PM2.5              Дамбадаржаа  168  168     168     168   168   168
# 8   PM2.5                   МҮОНРТ  168  168     168     168   168   168
# 9   PM2.5                   Налайх  180  180     180     180   180   180
# 10  PM2.5                    Нисэх  168  168     168     168   168   168
# 11  PM2.5                  Толгойт  168  168     168     168   168   168
# 12  PM2.5                 Хайлааст  165  165     165     165   165   165
# 13  PM2.5     Эрдэнэт 2-р цэцэрлэг  168  168     168     168   168   168
# 14  PM2.5      Эрдэнэт Хаядлын сан  168  168     168     168   168   168
#
#     station  aqi_us  value
# 0       168       0    168
# 1       144     144    144
# 2       168       0    168
# 3       168       0    168
# 4       125       0    125
# 5         0       0    167
# 6       168       0    168
# 7         0       0    168
# 8       168       0    168
# 9         0       0    180
# 10      168       0    168
# 11      168       0    168
# 12        0       0    165
# 13        0       0    168
# 14        0       0    168

# %%
avg
# Out:
#      type               station_mn        lat         lon     aqi_mn  \
# 0   PM2.5             1-р хороолол  47.917980  106.848060  31.791667
# 1   PM2.5  АНУ-ын Элчин сайдын яам  47.928000  106.929000  27.513889
# 2   PM2.5                  Амгалан  47.913430  106.997910  35.672619
# 3   PM2.5             Баруун 4 зам  47.915382  106.894196  26.297619
# 4   PM2.5                Баянхошуу  47.957560  106.822754  35.080000
# 5   PM2.5   Богд хааны ордон музей  47.896942  106.906390   4.317365
# 6   PM2.5             Бөхийн өргөө  47.917606  106.937360  18.583333
# 7   PM2.5              Дамбадаржаа  47.962982  106.932160  36.565476
# 8   PM2.5                   МҮОНРТ  47.929733  106.888626  26.791667
# 9   PM2.5                   Налайх  47.777195  107.252640  27.911111
# 10  PM2.5                    Нисэх  47.863940  106.779090  27.970238
# 11  PM2.5                  Толгойт  47.922497  106.794810  14.083333
# 12  PM2.5                 Хайлааст  47.958057  106.901665  21.800000
# 13  PM2.5     Эрдэнэт 2-р цэцэрлэг  49.033960  104.065790  26.613095
# 14  PM2.5      Эрдэнэт Хаядлын сан  49.021910  104.081730  14.291667
#
#        aqi_us      value
# 0         NaN  20.738095
# 1   57.965278  18.715278
# 2         NaN  22.785714
# 3         NaN  17.517857
# 4         NaN  22.344000
# 5         NaN   2.664671
# 6         NaN  12.559524
# 7         NaN  23.833333
# 8         NaN  16.827381
# 9         NaN  18.522222
# 10        NaN  18.470238
# 11        NaN   9.440476
# 12        NaN  14.060606
# 13        NaN  18.071429
# 14        NaN   9.738095

# %% [markdown]
# ## Translate Station Names

# %%
avg['station_mn'].values
# Out:
# array(['1-р хороолол', 'АНУ-ын Элчин сайдын яам', 'Амгалан',
#        'Баруун 4 зам', 'Баянхошуу', 'Богд хааны ордон музей',
#        'Бөхийн өргөө', 'Дамбадаржаа', 'МҮОНРТ', 'Налайх', 'Нисэх',
#        'Толгойт', 'Хайлааст', 'Эрдэнэт 2-р цэцэрлэг',
#        'Эрдэнэт Хаядлын сан'], dtype=object)

# %%
station_map = {'1-р хороолол':'1st Khoroolol', 'АНУ-ын Элчин сайдын яам':'US Embassy', 
               'Амгалан':'Amgalan', 'Баруун 4 зам':'West 4 Road', 'Богд хааны ордон музей':'Bogd Khan Museum', 
               'Дамбадаржаа':'Dambarajaa', 'МҮОНРТ':'MNB','Налайх':'Nalaikh', 
               'Нисэх':'Airport', 'Толгойт':'Tolgoit', 'Хайлааст':'Khailaast', 'Шархад':'Sharkhad',
               'Эрдэнэт вокзал':'Erdenet Train Station',  'Бөхийн өргөө':'Wrestling Palace', 'Баянхошуу':'Bayankhoshuu'}

# %%
avg['station_en'] = avg['station_mn'].map(station_map)

# %%
avg
# Out:
#      type               station_mn        lat         lon     aqi_mn  \
# 0   PM2.5             1-р хороолол  47.917980  106.848060  31.791667
# 1   PM2.5  АНУ-ын Элчин сайдын яам  47.928000  106.929000  27.513889
# 2   PM2.5                  Амгалан  47.913430  106.997910  35.672619
# 3   PM2.5             Баруун 4 зам  47.915382  106.894196  26.297619
# 4   PM2.5                Баянхошуу  47.957560  106.822754  35.080000
# 5   PM2.5   Богд хааны ордон музей  47.896942  106.906390   4.317365
# 6   PM2.5             Бөхийн өргөө  47.917606  106.937360  18.583333
# 7   PM2.5              Дамбадаржаа  47.962982  106.932160  36.565476
# 8   PM2.5                   МҮОНРТ  47.929733  106.888626  26.791667
# 9   PM2.5                   Налайх  47.777195  107.252640  27.911111
# 10  PM2.5                    Нисэх  47.863940  106.779090  27.970238
# 11  PM2.5                  Толгойт  47.922497  106.794810  14.083333
# 12  PM2.5                 Хайлааст  47.958057  106.901665  21.800000
# 13  PM2.5     Эрдэнэт 2-р цэцэрлэг  49.033960  104.065790  26.613095
# 14  PM2.5      Эрдэнэт Хаядлын сан  49.021910  104.081730  14.291667
#
#        aqi_us      value        station_en
# 0         NaN  20.738095     1st Khoroolol
# 1   57.965278  18.715278        US Embassy
# 2         NaN  22.785714           Amgalan
# 3         NaN  17.517857       West 4 Road
# 4         NaN  22.344000      Bayankhoshuu
# 5         NaN   2.664671  Bogd Khan Museum
# 6         NaN  12.559524  Wrestling Palace
# 7         NaN  23.833333        Dambarajaa
# 8         NaN  16.827381               MNB
# 9         NaN  18.522222           Nalaikh
# 10        NaN  18.470238           Airport
# 11        NaN   9.440476           Tolgoit
# 12        NaN  14.060606         Khailaast
# 13        NaN  18.071429               NaN
# 14        NaN   9.738095               NaN

# %% [markdown]
# ## Make Gaussian Model

# %%
# Create Bounding Box and Grid
X, Y = np.meshgrid(np.arange(106.695092, 107.151175, 0.002), np.arange(47.822221, 47.975652, 0.002))
kernel = Matern(nu=2.5)

# %%
### PM2.5 Model
gp25 = GaussianProcessRegressor(kernel=kernel, alpha=1e-10, n_restarts_optimizer=20)

points = avg[['lon','lat']].values
values = avg['aqi_mn'].values

# %% [markdown]
# | AQI_MN Value | Category Name                           | Resulting Cat |
# |--------------|-----------------------------------------|---------------|
# | 0-50         | Цэвэр (Clean)                           | 0             |
# | 51-100       | Хэвийн (Normal)                         | 1             |
# | 101-200      | Бага бохирдолтой (Low Pollution)        | 2             |
# | 201-300      | Бохирдолтой (Polluted)                  | 3             |
# | 301-400      | Их бохирдолтой (Very Polluted)          | 4             |
# | 401-500      | Маш их бохирдолтой (Extremely Polluted) | 5             |

# %%
values
# Out:
# array([31.79166667, 27.51388889, 35.67261905, 26.29761905, 35.08      ,
#         4.31736527, 18.58333333, 36.56547619, 26.79166667, 27.91111111,
#        27.9702381 , 14.08333333, 21.8       , 26.61309524, 14.29166667])

# %%
gp25.fit(points, values)
XY_pairs = np.column_stack([X.flatten(), Y.flatten()])
pm25_results = gp25.predict(XY_pairs)
pm25_pred = pd.DataFrame(XY_pairs, columns=['lon','lat'])
pm25_pred['aqi_mn_pred'] = pm25_results

# %%
## Clip values to have a minimum of 0
pm25_pred['aqi_mn_pred'] = pm25_pred['aqi_mn_pred'].clip(lower=0)

# %% [markdown]
# ## Make Heatmap Image

# %%
pm25_pred
# Out:
#               lon        lat  aqi_mn_pred
# 0      106.695092  47.822221     0.849390
# 1      106.697092  47.822221     0.933203
# 2      106.699092  47.822221     1.024319
# 3      106.701092  47.822221     1.123233
# 4      106.703092  47.822221     1.230449
# ...           ...        ...          ...
# 17628  107.143092  47.974221     0.031400
# 17629  107.145092  47.974221     0.028220
# 17630  107.147092  47.974221     0.025363
# 17631  107.149092  47.974221     0.022797
# 17632  107.151092  47.974221     0.020494
#
# [17633 rows x 3 columns]

# %%
bins = [0, 51, 101, 201, 301, 401, 10_000]
labels = [0, 1, 2, 3, 4, 5]

# %%
avg['aqi_cat'] = np.array(pd.cut(avg['aqi_mn'], bins, labels=labels))

# %%
pm25_pred['aqi_cat_pred'] = np.array(pd.cut(pm25_pred['aqi_mn_pred'], bins, labels=labels))

# %%
colorscale = ['#00e400', '#ffff00', '#ff7e00', '#ff0000', '#8f3f97', '#7e0023']

fig = go.Figure(data=
    go.Contour(
        z=pm25_pred['aqi_cat_pred'],
        x=pm25_pred['lon'],
        y=pm25_pred['lat'], 
        ncontours=100, 
        line = dict(width = 0),
        contours=dict(
            value = [[0, 50], [51,100], [101-200], [201-300], [301-400], [401-1000]],
            start=0,
            end=5,
            operation = "][",
            coloring='fill'
        ),
        colorscale=colorscale
    ))

fig.update_traces(showscale=False)
fig.update_layout(yaxis={'visible':False, 'showticklabels':False}, 
                  xaxis={'visible':False, 'showticklabels':False})
fig.update_layout(yaxis=dict(range=[Y.min(),Y.max()]), xaxis=dict(range=[X.min(),X.max()]))
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.write_image("contourpm25.png")

# %%
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="be44e7da-c9d6-48ee-8300-1db7a94bc2e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be44e7da-c9d6-48ee-8300-1db7a94bc2e6")) {                    Plotly.newPlot(                        "be44e7da-c9d6-48ee-8300-1db7a94bc2e6",                        [{"colorscale":[[0.0,"#00e400"],[0.2,"#ffff00"],[0.4,"#ff7e00"],[0.6,"#ff0000"],[0.8,"#8f3f97"],[1.0,"#7e0023"]],"contours":{"coloring":"fill","end":5,"operation":"][","start":0,"value":[[0,50],[51,100],[-99],[-99],[-99],[-599]]},"line":{"width":0},"ncontours":100,"x":[106.695092,106.697092,106.699092,106.70109199999999,106.70309199999998,106.70509199999998,106.70709199999997,106.70909199999997,106.71109199999997,106.71309199999996,106.71509199999996,106.71709199999995,106.71909199999995,106.72109199999994,106.72309199999994,106.72509199999993,106.72709199999993,106.72909199999992,106.73109199999992,106.73309199999991,106.73509199999991,106.7370919999999,106.7390919999999,106.7410919999999,106.74309199999989,106.74509199999989,106.74709199999988,106.74909199999988,106.75109199999987,106.75309199999987,106.75509199999986,106.75709199999986,106.75909199999985,106.76109199999985,106.76309199999984,106.76509199999984,106.76709199999983,106.76909199999983,106.77109199999983,106.77309199999982,106.77509199999982,106.77709199999981,106.7790919999998,106.7810919999998,106.7830919999998,106.78509199999979,106.78709199999979,106.78909199999978,106.79109199999978,106.79309199999977,106.79509199999977,106.79709199999976,106.79909199999976,106.80109199999976,106.80309199999975,106.80509199999975,106.80709199999974,106.80909199999974,106.81109199999973,106.81309199999973,106.81509199999972,106.81709199999972,106.81909199999971,106.82109199999971,106.8230919999997,106.8250919999997,106.8270919999997,106.82909199999969,106.83109199999969,106.83309199999968,106.83509199999968,106.83709199999967,106.83909199999967,106.84109199999966,106.84309199999966,106.84509199999965,106.84709199999965,106.84909199999964,106.85109199999964,106.85309199999963,106.85509199999963,106.85709199999962,106.85909199999962,106.86109199999962,106.86309199999961,106.8650919999996,106.8670919999996,106.8690919999996,106.87109199999959,106.87309199999959,106.87509199999958,106.87709199999958,106.87909199999957,106.88109199999957,106.88309199999956,106.88509199999956,106.88709199999956,106.88909199999955,106.89109199999955,106.89309199999954,106.89509199999954,106.89709199999953,106.89909199999953,106.90109199999952,106.90309199999952,106.90509199999951,106.90709199999951,106.9090919999995,106.9110919999995,106.9130919999995,106.91509199999949,106.91709199999949,106.91909199999948,106.92109199999948,106.92309199999947,106.92509199999947,106.92709199999946,106.92909199999946,106.93109199999945,106.93309199999945,106.93509199999944,106.93709199999944,106.93909199999943,106.94109199999943,106.94309199999942,106.94509199999942,106.94709199999942,106.94909199999941,106.9510919999994,106.9530919999994,106.9550919999994,106.95709199999939,106.95909199999939,106.96109199999938,106.96309199999938,106.96509199999937,106.96709199999937,106.96909199999936,106.97109199999936,106.97309199999935,106.97509199999935,106.97709199999935,106.97909199999934,106.98109199999934,106.98309199999933,106.98509199999933,106.98709199999932,106.98909199999932,106.99109199999931,106.99309199999931,106.9950919999993,106.9970919999993,106.9990919999993,107.00109199999929,107.00309199999928,107.00509199999928,107.00709199999928,107.00909199999927,107.01109199999927,107.01309199999926,107.01509199999926,107.01709199999925,107.01909199999925,107.02109199999924,107.02309199999924,107.02509199999923,107.02709199999923,107.02909199999922,107.03109199999922,107.0330919999992 ...

# %% [markdown]
# ## Make Geo Map

# %%
colorscale
# Out:
# ['#00e400', '#ffff00', '#ff7e00', '#ff0000', '#8f3f97', '#7e0023']

# %% [markdown]
# ### English Map

# %%
avg
# Out:
#      type               station_mn        lat         lon     aqi_mn  \
# 0   PM2.5             1-р хороолол  47.917980  106.848060  31.791667
# 1   PM2.5  АНУ-ын Элчин сайдын яам  47.928000  106.929000  27.513889
# 2   PM2.5                  Амгалан  47.913430  106.997910  35.672619
# 3   PM2.5             Баруун 4 зам  47.915382  106.894196  26.297619
# 4   PM2.5                Баянхошуу  47.957560  106.822754  35.080000
# 5   PM2.5   Богд хааны ордон музей  47.896942  106.906390   4.317365
# 6   PM2.5             Бөхийн өргөө  47.917606  106.937360  18.583333
# 7   PM2.5              Дамбадаржаа  47.962982  106.932160  36.565476
# 8   PM2.5                   МҮОНРТ  47.929733  106.888626  26.791667
# 9   PM2.5                   Налайх  47.777195  107.252640  27.911111
# 10  PM2.5                    Нисэх  47.863940  106.779090  27.970238
# 11  PM2.5                  Толгойт  47.922497  106.794810  14.083333
# 12  PM2.5                 Хайлааст  47.958057  106.901665  21.800000
# 13  PM2.5     Эрдэнэт 2-р цэцэрлэг  49.033960  104.065790  26.613095
# 14  PM2.5      Эрдэнэт Хаядлын сан  49.021910  104.081730  14.291667
#
#        aqi_us      value        station_en  aqi_cat
# 0         NaN  20.738095     1st Khoroolol        0
# 1   57.965278  18.715278        US Embassy        0
# 2         NaN  22.785714           Amgalan        0
# 3         NaN  17.517857       West 4 Road        0
# 4         NaN  22.344000      Bayankhoshuu        0
# 5         NaN   2.664671  Bogd Khan Museum        0
# 6         NaN  12.559524  Wrestling Palace        0
# 7         NaN  23.833333        Dambarajaa        0
# 8         NaN  16.827381               MNB        0
# 9         NaN  18.522222           Nalaikh        0
# 10        NaN  18.470238           Airport        0
# 11        NaN   9.440476           Tolgoit        0
# 12        NaN  14.060606         Khailaast        0
# 13        NaN  18.071429               NaN        0
# 14        NaN   9.738095               NaN        0

# %%
avg = avg[~avg['station_mn'].str.contains("Эрдэнэт")]

# %%
avg
# Out:
#      type               station_mn        lat         lon     aqi_mn  \
# 0   PM2.5             1-р хороолол  47.917980  106.848060  31.791667
# 1   PM2.5  АНУ-ын Элчин сайдын яам  47.928000  106.929000  27.513889
# 2   PM2.5                  Амгалан  47.913430  106.997910  35.672619
# 3   PM2.5             Баруун 4 зам  47.915382  106.894196  26.297619
# 4   PM2.5                Баянхошуу  47.957560  106.822754  35.080000
# 5   PM2.5   Богд хааны ордон музей  47.896942  106.906390   4.317365
# 6   PM2.5             Бөхийн өргөө  47.917606  106.937360  18.583333
# 7   PM2.5              Дамбадаржаа  47.962982  106.932160  36.565476
# 8   PM2.5                   МҮОНРТ  47.929733  106.888626  26.791667
# 9   PM2.5                   Налайх  47.777195  107.252640  27.911111
# 10  PM2.5                    Нисэх  47.863940  106.779090  27.970238
# 11  PM2.5                  Толгойт  47.922497  106.794810  14.083333
# 12  PM2.5                 Хайлааст  47.958057  106.901665  21.800000
#
#        aqi_us      value        station_en  aqi_cat
# 0         NaN  20.738095     1st Khoroolol        0
# 1   57.965278  18.715278        US Embassy        0
# 2         NaN  22.785714           Amgalan        0
# 3         NaN  17.517857       West 4 Road        0
# 4         NaN  22.344000      Bayankhoshuu        0
# 5         NaN   2.664671  Bogd Khan Museum        0
# 6         NaN  12.559524  Wrestling Palace        0
# 7         NaN  23.833333        Dambarajaa        0
# 8         NaN  16.827381               MNB        0
# 9         NaN  18.522222           Nalaikh        0
# 10        NaN  18.470238           Airport        0
# 11        NaN   9.440476           Tolgoit        0
# 12        NaN  14.060606         Khailaast        0

# %%
m = folium.Map([47.935776, 106.920458], 
               zoom_start=12, 
               no_touch=True, 
               maxBounds = [[47.822221,107.151175], [47.975652,106.695092]],
               minZoom=12,
               tiles='https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=' + mapbox_token,
               attr='Mapbox'
    )

folium.raster_layers.ImageOverlay(
    image='/work/contourpm25.png',
    name='PM2.5',
    bounds=[[47.822221,107.151175], [47.975652,106.695092]],
    opacity=0.2,
    interactive=False,
    cross_origin=False,
    zindex=1
).add_to(m)

for station in avg['station_en']:
    row = avg[avg['station_en'] == station]
    folium.CircleMarker(location=[row['lat'], row['lon']], 
                       radius=3,
                       tooltip=f"""{str(station)} station<br>
                                7-day Average AQI: {round(row['aqi_mn'].iat[0],0)}<br>
                                Dates: {start_date} - {end_date}""", 
                       color=colorscale[row['aqi_cat'].iat[0]], 
                       weight=7).add_to(m)

#colormap = cm.StepColormap(colorscale, index=[0,51,101,201,301,401, 500], vmin=0, vmax=500)
#colormap.caption = '7-day Average PM2.5 AQI, '
#colormap.add_to(m)

title_html = f'''
             <h3 align="center" style="font-size:16px;">7-day Air Quality Map for {start_date} to {end_date}</h3>
             '''
m.get_root().html.add_child(folium.Element(title_html))

m.save("pm25_map_en.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = true;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15307c8238a0d061df10f68ae6628974 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px;&quot;&gt;7-day Air Quality Map for 2023-04-20 to 2023-04-27&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15307c8238a0d061df10f68ae6628974&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_15307c8238a0d061df10f68ae6628974 = L.map(
#                 &quot;map_15307c8238a0d061df10f68ae6628974&quot;,
#                 {
#                     center: [47.935776, 106.920458],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     maxBounds: [[47.822221, 107.151175], [47.975652, 106.695092]],
#                     minZoom: 12,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90c34c31d5e9d01f564a2f89f6fde4c8 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=pk.eyJ1Ijoicm9iZXJ0cml0eiIsImEiOiJjam01dGZtcnIxNDJhM3ZtbWZlMHFjZHc1In0.01rvohTgnLlD4VDtrQZX8g&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_15307c8238a0d061df10f68ae6628974);
#
#
#             var image_overlay_0285108f65cb7463771c31d3d9536955 = L.imageOverlay(
#                 &quot;data:image/png;base64,...&quot;,
#                 [[47.822221, 107.151175], [47.975652, 106.695092]],
#                 {&quot;crossOrigin&quot;: false, &quot;interactive&quot;: false, &quot;opacity&quot;: 0.2, &quot;zindex&quot;: 1}
#             ).addTo(map_15307c8238a0d061df10f68ae6628974);
#
#
#             var circle_marker_a6a2d42d760205e39e010cc55e1a07f7 = L.circleMarker(
#                 [47.917980000000114, 106.84806000000017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00e400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00e400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_15307c8238a0d061df10f68ae6628974);
#
#
#             circle_marker_a6a2d42d760205e39e010cc55e1a07f7.bindTooltip(
#                 `&lt;div&gt;
#                      1st Khoroolol station&lt;br&gt;
#                                 7-day Average AQI: 32.0&lt;br&gt;
#                                 Dates: 2023-04-20 - 2023-04-27
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_5e960057add7fcb24883f19d648c51e2 = L.circleMarker(
#                 [47.927999999999905, 106.92900000000007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00e400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00e400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_15307c8238a0d061df10f68ae6628974);
#
#
#             circle_marker_5e960057add7fcb24883f19d648c51e2.bindTooltip(
#                 `&lt;div&gt;
#                      US Embassy station&lt;br&gt;
#                                 7-day Average AQI: 28.0&lt;br&gt;
#                                 Dates: 2023-04-20 - 2023-04-27
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_01289ee00ec672d6dc97a045069a0a4d = L.circleMarker(
#                 [47.91342999999983, 106.99790999999988],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00e400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00e400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_15307c8238a0d061df10f68ae6628974);
#
#
#             circle_marker_01289ee00ec672d6dc97a045069a0a4d.bindTooltip(
#                 `&lt;div&gt;
#                      Amgalan station&lt;br&gt;

# %% [markdown]
# ### Mongolian Map

# %%
m = folium.Map([47.935776, 106.920458], 
               zoom_start=12, 
               no_touch=True, 
               maxBounds = [[47.822221,107.151175], [47.975652,106.695092]],
               minZoom=12,
               tiles='https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=' + mapbox_token,
               attr='Mapbox'
    )

folium.raster_layers.ImageOverlay(
    image='/work/contourpm25.png',
    name='PM2.5',
    bounds=[[47.822221,107.151175], [47.975652,106.695092]],
    opacity=0.2,
    interactive=False,
    cross_origin=False,
    zindex=1
).add_to(m)

for station in avg['station_mn']:
    row = avg[avg['station_mn'] == station]
    folium.CircleMarker(location=[row['lat'], row['lon']], 
                       radius=3,
                       tooltip=f"""{str(station)} станц<br>
                                7 өдрийн дундаж АЧИ: {round(row['aqi_mn'].iat[0],0)}<br>
                                Огноо: {start_date} - {end_date}""",
                       color=colorscale[row['aqi_cat'].iat[0]], 
                       weight=7).add_to(m)

#colormap = cmp.StepColormap(colorscale, 
#                            index=[0,51,101,201,301,401, 500],
#                            vmin=0, vmax=500)
#colormap.caption = '7 хоногийн дундаж PM2.5 AQI'
#m.add_child(colormap)

title_html = f'''
             <h3 align="center" style="font-size:16px">Газрын зураг нь {start_date}-ноос {end_date} хүртэлх агаарын чанарын мэдээллийг ашигласан.</h3>
             '''
m.get_root().html.add_child(folium.Element(title_html))

m.save("pm25_map_mn.html")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = true;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2db63129c76cc9446438e64998ca38ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;Газрын зураг нь 2023-04-20-ноос 2023-04-27 хүртэлх агаарын чанарын мэдээллийг ашигласан.&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2db63129c76cc9446438e64998ca38ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2db63129c76cc9446438e64998ca38ea = L.map(
#                 &quot;map_2db63129c76cc9446438e64998ca38ea&quot;,
#                 {
#                     center: [47.935776, 106.920458],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     maxBounds: [[47.822221, 107.151175], [47.975652, 106.695092]],
#                     minZoom: 12,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0acc7891a034b919bf7a74b8b3eafed1 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/streets-v11/tiles/{z}/{x}/{y}?access_token=pk.eyJ1Ijoicm9iZXJ0cml0eiIsImEiOiJjam01dGZtcnIxNDJhM3ZtbWZlMHFjZHc1In0.01rvohTgnLlD4VDtrQZX8g&quot;,
#                 {&quot;attribution&quot;: &quot;Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2db63129c76cc9446438e64998ca38ea);
#
#
#             var image_overlay_9e0fa8353fadc0bb5b248aab59a433da = L.imageOverlay(
#                 &quot;data:image/png;base64,...&quot;,
#                 [[47.822221, 107.151175], [47.975652, 106.695092]],
#                 {&quot;crossOrigin&quot;: false, &quot;interactive&quot;: false, &quot;opacity&quot;: 0.2, &quot;zindex&quot;: 1}
#             ).addTo(map_2db63129c76cc9446438e64998ca38ea);
#
#
#             var circle_marker_9fb1e2bff018a5b37087ab638e03f469 = L.circleMarker(
#                 [47.917980000000114, 106.84806000000017],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00e400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00e400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_2db63129c76cc9446438e64998ca38ea);
#
#
#             circle_marker_9fb1e2bff018a5b37087ab638e03f469.bindTooltip(
#                 `&lt;div&gt;
#                      1-р хороолол станц&lt;br&gt;
#                                 7 өдрийн дундаж АЧИ: 32.0&lt;br&gt;
#                                 Огноо: 2023-04-20 - 2023-04-27
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_f7e4132b904154d507d7f39256a2fb9f = L.circleMarker(
#                 [47.927999999999905, 106.92900000000007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00e400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00e400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_2db63129c76cc9446438e64998ca38ea);
#
#
#             circle_marker_f7e4132b904154d507d7f39256a2fb9f.bindTooltip(
#                 `&lt;div&gt;
#                      АНУ-ын Элчин сайдын яам станц&lt;br&gt;
#                                 7 өдрийн дундаж АЧИ: 28.0&lt;br&gt;
#                                 Огноо: 2023-04-20 - 2023-04-27
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_0008df06f12ec8e971cde6342ab1dd24 = L.circleMarker(
#                 [47.91342999999983, 106.99790999999988],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00e400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#00e400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 7}
#             ).addTo(map_2db63129c76cc9446438e64998ca38ea);
#
#
#             circle_marker_0008df06f12ec8e971cde6342ab1dd24.bindTooltip(
#                 `&lt;div&gt;

# %% [markdown]
# ## Copy Map and Push to Github

# %%
# !git -C hazegazer_maps pull
# Out:
# From https://github.com/robertritz/hazegazer_maps
#    99b1c5e..baaa7f7  main       -> origin/main
# Already up to date.

# %%
# !ls
# Out:
# contourpm25.png  hazegazer_maps    PM2.5Map.ipynb    requirements.txt
# data		 pm25_map_en.html  pm25_map_mn.html

# %%
# !cp pm25_map_en.html hazegazer_maps/pm25_map_en.html
# !cp pm25_map_mn.html hazegazer_maps/pm25_map_mn.html
# !cp PM2.5Map.ipynb hazegazer_maps/PM2.5Map.ipynb

# %%
today = datetime.datetime.today().strftime("%Y-%m-%d")

# %%
# !git config --global user.name "Robert Ritz"
# !git config --global user.email robertritz@outlook.com

# %%
# !git -C hazegazer_maps add --all
# !git -C hazegazer_maps commit -m 'Pushed new map - {today}'
# Out:
# [main 92e819f] Pushed new map - 2023-04-27
#  2 files changed, 148 insertions(+), 148 deletions(-)

# %%
repo_url = f'https://{github_username}:{github_key}@github.com/robertritz/hazegazer_maps.git'

# %%
# !git -C hazegazer_maps push {repo_url}
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.97 KiB | 1.97 MiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/robertritz/hazegazer_maps.git
#    baaa7f7..92e819f  main -> main

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=bd425baf-186b-4ebf-be2f-f59ef7ad3c26' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
